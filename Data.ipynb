# %%
import moxing as mox
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/sdata",dst_url="./data")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/resnet",dst_url="./resnet")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/config.py",dst_url="./config.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/data.py",dst_url="./data.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/model.py",dst_url="./model.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/preprocess-images.py",dst_url="./preprocess-images.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/preprocess-vocab.py",dst_url="./preprocess-vocab.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/train.py",dst_url="./train.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/utils.py",dst_url="./utils.py")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/resnet152-95e0e999.pth",dst_url="/home/ma-user/.cache/torch/checkpoints/resnet152-95e0e999.pth")
mox.file.copy_parallel(src_url="s3://syh-mindspore/final/resnet-14x14.h5",dst_url="./resnet-14x14.h5")
# !python preprocess-vocab.py
# Out:
# INFO:root:Using MoXing-v1.17.3-d858ff4a
# INFO:root:Using OBS-Python-SDK-3.20.9.1

# %%
# !python data.py

# %%
import config
import data
import model
import utils
import mindspore.context as context
from mindspore import nn, Tensor
context.set_context(device_target="Ascend")
norm = nn.Norm(axis=1, keep_dims=True)

# %%
train_loader = data.get_loader(train=True)
net = model.Net(train_loader.source.num_tokens)
for test in train_loader.create_dict_iterator():
    v = test["v"]
    q = test["q"]
    a = test["a"]
    item = test["item"]
    q_len = test["q_length"]
    out = net(v, q, q_len)
# Out:
# (128, 2048, 14, 14)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-63889a093c1e> in <module>
#       4     v = test["v"]
#       5     print(v.shape)
# ----> 6     print(norm(v).expand_as(v).shape)
#       7     temp = norm(v).expand_as(v) + 1e-8
#       8
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/common/tensor.py in expand_as(self, x)
#     438         """
#     439         self.init_check()
# --> 440         return tensor_operator_registry.get('broadcast_to')(x.shape)(self)
#     441
#     442     def abs(self):
#
# ~/miniconda3/envs/MindSpore-python3.7-aarch64/lib/python3.7/site-packages/mindspore/ops/primitive.py in __call__(self, *args)
#     186         if should_elim:
#     187             return output
# --> 188         return _run_op(self, self.name, args)
#     189
# ...
